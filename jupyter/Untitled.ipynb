# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col
# import pymongo

# # Создание сессии Spark с конфигурацией для подключения к MongoDB
# spark = SparkSession.builder.appName("Kinopoisk").getOrCreate()

spark = SparkSession.builder \
    .appName("MongoDB Connection") \
    .master("local[*]").config("spark.mongodb.input.uri", "mongodb://mongodb:27017/movies_db.movies") \
    .config("spark.mongodb.output.uri", "mongodb://mongodb:27017/movies_db.movies") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.1") \
    .getOrCreate()

# logger = spark._jvm.org.apache.log4j
# logger.LogManager.getRootLogger().setLevel(logger.Level.FATAL)

# Чтение данных из MongoDB
df = spark.read.format("mongo").load()

# Обработка данных (например, показ первых 5 записей)|
df.show()

# # Предобработка данных (Пример: Извлечение некоторых полей и индексирование категорий)
# df = df.select("name", "year", df["rating.kp"].alias("rating_kp"), df["votes.kp"].alias("votes_kp"))

# df.show(5)
# df = df.dropna()

# # Индексирование категориальных переменных
# indexer = StringIndexer(inputCol="name", outputCol="nameIndex")
# df = indexer.fit(df).transform(df)

# # Формирование вектора признаков
# assembler = VectorAssembler(inputCols=["year", "votes_kp", "nameIndex"], outputCol="features")
# df = assembler.transform(df)

# # Разделение на тренировочные и тестовые данные
# train_data, test_data = df.randomSplit([0.8, 0.2])

# # Обучение модели линейной регрессии
# lr = LinearRegression(labelCol="rating_kp", featuresCol="features")
# lr_model = lr.fit(train_data)

# # Предсказания
# predictions = lr_model.transform(test_data)
# predictions.select("features", "rating_kp", "prediction").show(10)

# # Оценка модели
# evaluator = RegressionEvaluator(labelCol="rating_kp", predictionCol="prediction", metricName="rmse")
# rmse = evaluator.evaluate(predictions)
# print(f"RMSE: {rmse}")

spark.stop()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----+
# |                 _id|     alternativeName|           countries|         description|              genres|     id|                name|              poster|              rating|    shortDescription|year|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----+
# |{667af3da2d62e33d...|BTS: Blood Sweat ...|     [{Корея Южная}]|                NULL|[{короткометражка...|1201206|                NULL|        {NULL, NULL}|{9.393, 0.0, 0.0,...|                NULL|2016|
# |{667af3da2d62e33d...|Lords of the Lock...|             [{США}]|                NULL|[{для взрослых}, ...|1252447|    Лорды раздевалки|        {NULL, NULL}|{9.382, 9.4, 0.0,...|                NULL|1999|
# |{667af3da2d62e33d...|                NULL|          [{Россия}]|«Попкульт» — это ...|  [{документальный}]|5260016|            Попкульт|{https://image.op...|{9.349, 0.0, 0.0,...|                NULL|2022|
# |{667af3da2d62e33d...|Team Hot Wheels: ...|             [{США}]|В Хот Вилс появля...|[{мультфильм}, {д...| 962472|Hot Wheels. За гр...|{https://image.op...|{9.321, 6.9, 0.0,...|Мальчик помогает ...|2015|
# |{667af3da2d62e33d...|                NULL|          [{Россия}]|История о четырех...|[{мультфильм}, {ф...|1072974|       Герои Энвелла|{https://image.op...|{9.287, 0.0, 0.0,...|Школьники-геймеры...|2017|
# |{667af3da2d62e33d...|                    |             [{США}]|Астрофизик Нил Де...|  [{документальный}]|1309325|              Космос|{https://image.op...|{9.27, 0.0, 0.0, ...|Нил Деграсс Тайсо...|2019|
# |{667af3da2d62e33d...|Team Hot Wheels: ...|             [{США}]|Герои команды Хот...|[{мультфильм}, {д...| 952236|Hot Wheels. Мегат...|{https://image.op...|{9.255, 6.2, 0.0,...|Друзья-гонщики ст...|2015|
# |{667af3da2d62e33d...|          SolarBalls|[{США}, {Великобр...|Неизведанный и да...|[{мультфильм}, {ф...|5444474|    Шаранутый космос|{https://image.op...|{9.234, 9.5, 0.0,...|Астронавт-новичок...|2022|
# |{667af3da2d62e33d...|             Friends|             [{США}]|Шестеро друзей – ...|[{комедия}, {мело...|  77044|              Друзья|{https://image.op...|{9.232, 8.9, 0.0,...|Шестеро друзей, д...|1994|
# |{667af3da2d62e33d...|Threat Level Midn...|[{Великобритания}...|                NULL|[{короткометражка...|1339977|Уровень тревоги: ...|{https://image.op...|{9.23, 9.6, 0.0, ...|                NULL|2011|
# |{667af3da2d62e33d...|  Hamilton's America|             [{США}]|Рассказ о жизни а...|[{мюзикл}, {биогр...|1003587|           Гамильтон|{https://image.op...|{9.228, 8.3, 7.6,...|                NULL|2016|
# |{667af3da2d62e33d...|                NULL|          [{Россия}]|В марте 2018 года...|  [{документальный}]|2500772|Жизнь человека. П...|{https://image.op...|{9.212, 0.0, 0.0,...|Как принять диагн...|2020|
# |{667af3da2d62e33d...|                NULL|            [{СССР}]|Жил-был пёс. Верн...|[{мультфильм}, {к...|  45319|         Жил-был пёс|{https://image.op...|{9.196, 8.4, 0.0,...|Волк помогает ста...|1982|
# |{667af3da2d62e33d...|        BTS 본보야지|     [{Корея Южная}]|                    |     [{реальное ТВ}]|1399205|        BTS 본보야지|        {NULL, NULL}|{9.195, 9.4, 0.0,...|                NULL|2016|
# |{667af3da2d62e33d...|     Nature’s Cutest|        [{Германия}]|Если бы вас попро...|     [{реальное ТВ}]|5461779|Самые милые существа|{https://image.op...|{9.191, 0.0, 0.0,...|Как детеныши разн...|2021|
# |{667af3da2d62e33d...|Depeche Mode: Dev...|  [{Великобритания}]|Выступление Depec...|[{документальный}...| 351771|                NULL|{https://image.op...|{9.174, 9.1, 0.0,...|                NULL|1993|
# |{667af3da2d62e33d...|                NULL|          [{Россия}]|Документальный фи...|  [{документальный}]| 674243|     Счастливые люди|{https://image.op...|{9.173, 8.7, 0.0,...|                NULL|2008|
# |{667af3da2d62e33d...|Miniforce: New He...|     [{Корея Южная}]|Приквел популярно...|[{мультфильм}, {п...|1111028|Минифорс. Новые г...|{https://image.op...|{9.162, 0.0, 0.0,...|Миниатюрные звери...|2016|
# |{667af3da2d62e33d...|     Planet Earth II|[{Великобритания}...|Дэвид Аттенборо д...|  [{документальный}]|1007472|     Планета Земля 2|{https://image.op...|{9.157, 9.5, 0.0,...|                NULL|2016|
# |{667af3da2d62e33d...|The Filthy Frank ...|[{США}, {Япония},...|Шоу повествует о ...|[{короткометражка...|1043658| Шоу Грязного Фрэнка|{https://image.op...|{9.151, 9.2, 0.0,...|                NULL|2011|
# +--------------------+--------------------+--------------------+--------------------+--------------------+-------+--------------------+--------------------+--------------------+--------------------+----+
# only showing top 20 rows
